# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\dummy\anaconda3\anaconda\lib\site-packages (4.8.0.76)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\dummy\anaconda3\anaconda\lib\site-packages (from opencv-python) (1.23.5)

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# # Original Picture

# %%
image = cv2.imread(r'C:\Users\Dummy\Desktop\images.jpg')
cv2.imshow("Original Image", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # GRAY SCALE

# %%
gray_image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
cv2.imshow("Gray Scale Image",gray_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # RESIZE

# %%
new_size = (100, 70)
resized_image = cv2.resize(image,new_size)
cv2.imshow("Resize Image",resized_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # SUBPLOTS

# %%
fig = plt.figure(figsize=(10, 8))
rows = 2
columns = 2


fig.add_subplot(rows, columns, 1)
plt.imshow(gray_image, cmap='gray')
plt.axis('off')
plt.title("Gray Scale Image")

fig.add_subplot(rows, columns, 2)
plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title("Resized Image")

plt.tight_layout()
plt.show()
