# %% [markdown]
# # Import Libraries

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Original Picture

# %%
image = cv2.imread(r'C:\Users\Dummy\Desktop\images.jpg')
cv2.imshow("Original Image", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Blurred Picture

# %%
blurred_image = cv2.GaussianBlur(image,(5, 5), 0)
cv2.imshow("Blurred Image",blurred_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Reigon Of Interest

# %%
roi = image[50:200, 150:350]
cv2.imshow("ROI", roi)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # SUBPLOTS

# %%
fig=plt.figure(figsize=(10,8))
rows=2
column=2

fig.add_subplot(rows,column,1)
plt.imshow(blurred_image)
plt.axis('off')
plt.title("Blurred")


fig.add_subplot(rows,column,2)
plt.imshow(roi)
plt.axis('off')
plt.title("Reigon of Interest")
# Out:
# Text(0.5, 1.0, 'Reigon of Interest')
